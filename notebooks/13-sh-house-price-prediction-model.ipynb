# %%
# import all the libraries
import os
import sys

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error
from xgboost import XGBRegressor

# import python scripts we created to help with feature engineering
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.helpers import identify_highly_correlated_features, one_hot, identify_low_variance_features, identify_missing_data, feature_importance_plot
from src.learning_curve_plot import learning_curve_plot

# %%
housing_df = pd.read_csv("../data/housing_df.csv")
housing_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0           60.0       RL         65.0   8450.0   Pave   NaN      Reg  \
# 1           20.0       RL         80.0   9600.0   Pave   NaN      Reg
# 2           60.0       RL         68.0  11250.0   Pave   NaN      IR1
# 3           70.0       RL         60.0   9550.0   Pave   NaN      IR1
# 4           60.0       RL         84.0  14260.0   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455        60.0       RL         62.0   7917.0   Pave   NaN      Reg
# 1456        20.0       RL         85.0  13175.0   Pave   NaN      Reg
# 1457        70.0       RL         66.0   9042.0   Pave   NaN      Reg
# 1458        20.0       RL         68.0   9717.0   Pave   NaN      Reg
# 1459        20.0       RL         75.0   9937.0   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... 3SsnPorch ScreenPorch  PoolArea
# 0            Lvl    AllPub    Inside  ...       0.0         0.0       0.0  \
# 1            Lvl    AllPub       FR2  ...       0.0         0.0       0.0
# 2            Lvl    AllPub    Inside  ...       0.0         0.0       0.0
# 3            Lvl    AllPub    Corner  ...       0.0         0.0       0.0
# 4            Lvl    AllPub       FR2  ...       0.0         0.0       0.0
# ...          ...       ...       ...  ...       ...         ...       ...
# 1455         Lvl    AllPub    Inside  ...       0.0         0.0       0.0
# 1456         Lvl    AllPub    Inside  ...       0.0         0.0       0.0
# 1457         Lvl    AllPub    Inside  ...       0.0         0.0       0.0
# 1458         Lvl    AllPub    Inside  ...       0.0         0.0       0.0
# 1459         Lvl    AllPub    Inside  ...       0.0         0.0       0.0
#
#       PoolQC  Fence  MiscFeature MiscVal  MoSold  YrSold    target
# 0        NaN    NaN          NaN     0.0     2.0  2008.0  208500.0
# 1        NaN    NaN          NaN     0.0     5.0  2007.0  181500.0
# 2        NaN    NaN          NaN     0.0     9.0  2008.0  223500.0
# 3        NaN    NaN          NaN     0.0     2.0  2006.0  140000.0
# 4        NaN    NaN          NaN     0.0    12.0  2008.0  250000.0
# ...      ...    ...          ...     ...     ...     ...       ...
# 1455     NaN    NaN          NaN     0.0     8.0  2007.0  175000.0
# 1456     NaN  MnPrv          NaN     0.0     2.0  2010.0  210000.0
# 1457     NaN  GdPrv         Shed  2500.0     5.0  2010.0  266500.0
# 1458     NaN    NaN          NaN     0.0     4.0  2010.0  142125.0
# 1459     NaN    NaN          NaN     0.0     6.0  2008.0  147500.0
#
# [1460 rows x 60 columns]

# %% [markdown]
# ### Explore the Data

# %%
pd.set_option('display.max_columns', None) # you can use this code to view all columns

housing_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0        60.0       RL         65.0   8450.0   Pave   NaN      Reg  \
# 1        20.0       RL         80.0   9600.0   Pave   NaN      Reg
# 2        60.0       RL         68.0  11250.0   Pave   NaN      IR1
# 3        70.0       RL         60.0   9550.0   Pave   NaN      IR1
# 4        60.0       RL         84.0  14260.0   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope BldgType  OverallQual
# 0         Lvl    AllPub    Inside       Gtl     1Fam          7.0  \
# 1         Lvl    AllPub       FR2       Gtl     1Fam          6.0
# 2         Lvl    AllPub    Inside       Gtl     1Fam          7.0
# 3         Lvl    AllPub    Corner       Gtl     1Fam          7.0
# 4         Lvl    AllPub       FR2       Gtl     1Fam          8.0
#
#    OverallCond  YearBuilt  YearRemodAdd MasVnrType  MasVnrArea ExterQual
# 0          5.0     2003.0        2003.0    BrkFace       196.0        Gd  \
# 1          8.0     1976.0        1976.0        NaN         0.0        TA
# 2          5.0     2001.0        2002.0    BrkFace       162.0        Gd
# 3          5.0     1915.0        1970.0        NaN         0.0        TA
# 4          5.0     2000.0        2000.0    BrkFace       350.0        Gd
#
#   ExterCond BsmtQual BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF
# 0        TA       Gd       TA           No       706.0         0.0      150.0  \
# 1        TA       Gd       TA           Gd       978.0         0.0      284.0
# 2        TA       Gd       TA           Mn       486.0         0.0      434.0
# 3        TA       TA       Gd           No       216.0         0.0      540.0
# 4        TA       Gd       TA           Av       655.0         0.0      490.0
#
#    TotalBsmtSF HeatingQC CentralAir  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0        856.0        Ex          Y     856.0     854.0           0.0  \
# 1       1262.0        Ex          Y    1262.0       0.0           0.0
# 2        920.0        Ex          Y     920.0     866.0           0.0
# 3        756.0        Gd          Y     961.0     756.0           0.0
# 4       1145.0        Ex          Y    1145.0    1053.0           0.0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr
# 0     1710.0           1.0           0.0       2.0       1.0           3.0  \
# 1     1262.0           0.0           1.0       2.0       0.0           3.0
# 2     1786.0           1.0           0.0       2.0       1.0           3.0
# 3     1717.0           1.0           0.0       1.0       0.0           3.0
# 4     2198.0           1.0           0.0       2.0       1.0           4.0
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd  Fireplaces  GarageYrBlt
# 0           1.0          Gd           8.0         0.0       2003.0  \
# 1           1.0          TA           6.0         1.0       1976.0
# 2           1.0          Gd           6.0         1.0       2001.0
# 3           1.0          Gd           7.0         1.0       1998.0
# 4           1.0          Gd           9.0         1.0       2000.0
#
#   GarageFinish  GarageCars  GarageArea PavedDrive  WoodDeckSF  OpenPorchSF
# 0          RFn         2.0       548.0          Y         0.0         61.0  \
# 1          RFn         2.0       460.0          Y       298.0          0.0
# 2          RFn         2.0       608.0          Y         0.0         42.0
# 3          Unf         3.0       642.0          Y         0.0         35.0
# 4          RFn         3.0       836.0          Y       192.0         84.0
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature
# 0            0.0        0.0          0.0       0.0    NaN   NaN         NaN  \
# 1            0.0        0.0          0.0       0.0    NaN   NaN         NaN
# 2            0.0        0.0          0.0       0.0    NaN   NaN         NaN
# 3          272.0        0.0          0.0       0.0    NaN   NaN         NaN
# 4            0.0        0.0          0.0       0.0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold    target
# 0      0.0     2.0  2008.0  208500.0
# 1      0.0     5.0  2007.0  181500.0
# 2      0.0     9.0  2008.0  223500.0
# 3      0.0     2.0  2006.0  140000.0
# 4      0.0    12.0  2008.0  250000.0

# %%
# check the shape of the data

housing_df.shape

# that's a lot of columns! We have data on 1460 houses.
# Out:
# (1460, 60)

# %%
# check the info of the data

housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 60 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   float64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   float64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  BldgType       1460 non-null   object
#  12  OverallQual    1460 non-null   float64
#  13  OverallCond    1460 non-null   float64
#  14  YearBuilt      1460 non-null   float64
#  15  YearRemodAdd   1460 non-null   float64
#  16  MasVnrType     588 non-null    object
#  17  MasVnrArea     1452 non-null   float64
#  18  ExterQual      1460 non-null   object
#  19  ExterCond      1460 non-null   object
#  20  BsmtQual       1423 non-null   object
#  21  BsmtCond       1423 non-null   object
#  22  BsmtExposure   1422 non-null   object
#  23  BsmtFinSF1     1460 non-null   float64
#  24  BsmtFinSF2     1460 non-null   float64
#  25  BsmtUnfSF      1460 non-null   float64
#  26  TotalBsmtSF    1460 non-null   float64
#  27  HeatingQC      1460 non-null   object
#  28  CentralAir     1460 non-null   object
#  29  1stFlrSF       1460 non-null   float64
#  30  2ndFlrSF       1460 non-null   float64
#  31  LowQualFinSF   1460 non-null   float64
#  32  GrLivArea      1460 non-null   float64
#  33  BsmtFullBath   1460 non-null   float64
#  34  BsmtHalfBath   1460 non-null   float64
#  35  FullBath       1460 non-null   float64
#  36  HalfBath       1460 non-null   float64
#  37  BedroomAbvGr   1460 non-null   float64
#  38  KitchenAbvGr   1460 non-null   float64
#  39  KitchenQual    1460 non-null   object
#  40  TotRmsAbvGrd   1460 non-null   float64
#  41  Fireplaces     1460 non-null   float64
#  42  GarageYrBlt    1379 non-null   float64
#  43  GarageFinish   1379 non-null   object
#  44  GarageCars     1460 non-null   float64
#  45  GarageArea     1460 non-null   float64
#  46  PavedDrive     1460 non-null   object
#  47  WoodDeckSF     1460 non-null   float64
#  48  OpenPorchSF    1460 non-null   float64
#  49  EnclosedPorch  1460 non-null   float64
#  50  3SsnPorch      1460 non-null   float64
#  51  ScreenPorch    1460 non-null   float64
#  52  PoolArea       1460 non-null   float64
#  53  PoolQC         7 non-null      object
#  54  Fence          281 non-null    object
#  55  MiscFeature    54 non-null     object
#  56  MiscVal        1460 non-null   float64
#  57  MoSold         1460 non-null   float64
#  58  YrSold         1460 non-null   float64
#  59  target         1460 non-null   float64
# dtypes: float64(37), object(23)
# memory usage: 684.5+ KB

# %%
# identify features with low std

housing_df_numerical = housing_df.select_dtypes(["int64", "float64"])

identify_low_variance_features(housing_df_numerical, std_threshold=0.01)
# Out:
# number of low variance features: 0
# low variance features: []
# []

# %%
# check the distribution of the target

sns.distplot(housing_df.target);

# question: do you see any skew in the data?
# Out:
# /var/folders/gs/c69h38_15hb4fnkpnc9gvksm0000gn/T/ipykernel_50018/1466722119.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housing_df.target);

# %%
# look at highly correlated variables

plt.figure(figsize=(20,12))
sns.heatmap(housing_df.corr(numeric_only = True),annot=True, linewidth=2)
plt.tight_layout()

# %%
identify_highly_correlated_features(housing_df, correlation_threshold=0.85)

# we have one highly correlated feature which we will drop in the feature engineering section
# Out:
#   corr_feature drop_feature  correlation_values
# 0   GarageCars   GarageArea                0.88

# %%
# visualising the target which is a continuous variable

housing_df.target.describe()

# some slight positive skew - this can be identified with the mode less than the median less than the mean
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: target, dtype: float64

# %%
print("mode of the housing_df", list(housing_df.target.mode()))
# Out:
# mode of the housing_df [140000.0]

# %%
sns.distplot(housing_df.target);

# visualisation also shows signs of skew
# Out:
# /var/folders/gs/c69h38_15hb4fnkpnc9gvksm0000gn/T/ipykernel_50018/1944520256.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housing_df.target);

# %%
sns.boxplot(housing_df.target);

# outliers in target, which we may want to remove in a future iteration

# %%
# Bonus

# identfiying features that are highly correlated with the target

housing_df.drop('target', axis=1).corrwith(housing_df.target, numeric_only = True).plot(kind='bar', grid=True, figsize=(20, 10), 
                                                        title="Correlation with the target feature")
plt.tight_layout()

# exang has the highest postive correlation, closely followed by oldpeak, slope and thal

# %%
# what about the other numerical variables

plt.rcParams["figure.figsize"] = (20,20)

housing_df.hist();

# because of the amount of skewed data, please use tree based models only

# %%
# Identify missing data
# before doing any encoding, lets identify missing data

missing_value_df = identify_missing_data(housing_df) 
missing_value_df
# Out:
#          feature  percent_missing data_type
# 0         PoolQC            99.52    object
# 1    MiscFeature            96.30    object
# 2          Alley            93.77    object
# 3          Fence            80.75    object
# 4     MasVnrType            59.73    object
# 5    LotFrontage            17.74   float64
# 6    GarageYrBlt             5.55   float64
# 7   GarageFinish             5.55    object
# 8   BsmtExposure             2.60    object
# 9       BsmtQual             2.53    object
# 10      BsmtCond             2.53    object
# 11    MasVnrArea             0.55   float64

# %%
print("# of features with missing values:", missing_value_df.shape[0])
# Out:
# # of features with missing values: 12

# %% [markdown]
# The goal of EDA is to understand the data and identify if we need to do any additional data cleaning or feature engineering.
# - We do not have any features with low standard deviation, so we do not have drop any additional features
# - We have one pair of highly correlated features (positive or negative), which we will drop when we do our feature engineering
# - We have 23 features with data type object, so we have to do additonal encoding in the feature engineering section
# - We have 12 features with missing data, so we have to handle this

# %% [markdown]
# ### Data Cleaning

# %%
# drop features which have more than 60% missing values
# identify features which have more than 60% missing data

threshold = 60

cols_to_drop = list(missing_value_df[missing_value_df.percent_missing > threshold].feature)
print("number of columns to drop:", len(cols_to_drop))
print(cols_to_drop)
# Out:
# number of columns to drop: 4
# ['PoolQC', 'MiscFeature', 'Alley', 'Fence']

# %%
# drop the features with more than 60% missing data

housing_df_cleaned = housing_df.drop(cols_to_drop, axis = 1)

# check the variables are dropped 
print(housing_df.shape)
print(housing_df_cleaned.shape)
# Out:
# (1460, 60)
# (1460, 56)

# %%
# identify duplicates
# the data set has no duplicated data

housing_df_cleaned[housing_df_cleaned.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, BldgType, OverallQual, OverallCond, YearBuilt, YearRemodAdd, MasVnrType, MasVnrArea, ExterQual, ExterCond, BsmtQual, BsmtCond, BsmtExposure, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Fireplaces, GarageYrBlt, GarageFinish, GarageCars, GarageArea, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, target]
# Index: []

# %% [markdown]
# ### Feature Engineering

# %%
# handling missing data
# reminder of missing data

missing_value_df = identify_missing_data(housing_df_cleaned)
missing_value_df
# Out:
#         feature  percent_missing data_type
# 0    MasVnrType            59.73    object
# 1   LotFrontage            17.74   float64
# 2   GarageYrBlt             5.55   float64
# 3  GarageFinish             5.55    object
# 4  BsmtExposure             2.60    object
# 5      BsmtCond             2.53    object
# 6      BsmtQual             2.53    object
# 7    MasVnrArea             0.55   float64

# %%
# replace all categorical (data type object) missing values with Unknown --- Option 1 

housing_df_cleaned['GarageFinish'].fillna('Unknown', inplace=True)
housing_df_cleaned['BsmtExposure'].fillna('Unknown', inplace=True)
housing_df_cleaned['BsmtCond'].fillna('Unknown', inplace=True)
housing_df_cleaned['BsmtQual'].fillna('Unknown', inplace=True)
housing_df_cleaned['MasVnrType'].fillna('Unknown', inplace=True)

# %%
# replace all categorical (data type object) missing values with Unknown --- Option 2

missing_value_df = identify_missing_data(housing_df_cleaned)
categorical_cols = list(missing_value_df[missing_value_df.data_type == 'object'].feature)
print("number of categorical cols with missing data:", len(categorical_cols))
    
for c in categorical_cols:
    print("replacing missing values for:", c)
    housing_df_cleaned[c].fillna('Unknown', inplace=True)
# Out:
# number of categorical cols with missing data: 0

# %%
# look for missing data

missing_value_df = identify_missing_data(housing_df_cleaned)
missing_value_df
# Out:
#        feature  percent_missing data_type
# 0  LotFrontage            17.74   float64
# 1  GarageYrBlt             5.55   float64
# 2   MasVnrArea             0.55   float64

# %%
# replace all numerical (data type object) missing values with Unknown --- Option 1 

housing_df_cleaned['LotFrontage'].fillna(0, inplace=True)
housing_df_cleaned['GarageYrBlt'].fillna(0, inplace=True)
housing_df_cleaned['MasVnrArea'].fillna(0, inplace=True)

# %%
# replace all numerical missing (data type int, float or bool) values with 0 --- Option 2
missing_value_df = identify_missing_data(housing_df)
numerical_cols = list(missing_value_df[(missing_value_df.data_type == 'float64') |(missing_value_df.data_type == 'int64')].feature)
print("number of numerical cols with missing data:", len(numerical_cols))

for n in numerical_cols:
    print("replacing missing values for:", n)
    housing_df_cleaned[n].fillna(0, inplace=True)
# Out:
# number of numerical cols with missing data: 3
# replacing missing values for: LotFrontage
# replacing missing values for: GarageYrBlt
# replacing missing values for: MasVnrArea

# %%
# check do we have any missing data left

missing_value_df = identify_missing_data(housing_df_cleaned)
missing_value_df
# Out:
# Empty DataFrame
# Columns: [feature, percent_missing, data_type]
# Index: []

# %%
# check the info as a reminder - we have 19 variables with object data type that needs encoding

housing_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 56 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   float64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   float64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  BldgType       1460 non-null   object
#  11  OverallQual    1460 non-null   float64
#  12  OverallCond    1460 non-null   float64
#  13  YearBuilt      1460 non-null   float64
#  14  YearRemodAdd   1460 non-null   float64
#  15  MasVnrType     1460 non-null   object
#  16  MasVnrArea     1460 non-null   float64
#  17  ExterQual      1460 non-null   object
#  18  ExterCond      1460 non-null   object
#  19  BsmtQual       1460 non-null   object
#  20  BsmtCond       1460 non-null   object
#  21  BsmtExposure   1460 non-null   object
#  22  BsmtFinSF1     1460 non-null   float64
#  23  BsmtFinSF2     1460 non-null   float64
#  24  BsmtUnfSF      1460 non-null   float64
#  25  TotalBsmtSF    1460 non-null   float64
#  26  HeatingQC      1460 non-null   object
#  27  CentralAir     1460 non-null   object
#  28  1stFlrSF       1460 non-null   float64
#  29  2ndFlrSF       1460 non-null   float64
#  30  LowQualFinSF   1460 non-null   float64
#  31  GrLivArea      1460 non-null   float64
#  32  BsmtFullBath   1460 non-null   float64
#  33  BsmtHalfBath   1460 non-null   float64
#  34  FullBath       1460 non-null   float64
#  35  HalfBath       1460 non-null   float64
#  36  BedroomAbvGr   1460 non-null   float64
#  37  KitchenAbvGr   1460 non-null   float64
#  38  KitchenQual    1460 non-null   object
#  39  TotRmsAbvGrd   1460 non-null   float64
#  40  Fireplaces     1460 non-null   float64
#  41  GarageYrBlt    1460 non-null   float64
#  42  GarageFinish   1460 non-null   object
#  43  GarageCars     1460 non-null   float64
#  44  GarageArea     1460 non-null   float64
#  45  PavedDrive     1460 non-null   object
#  46  WoodDeckSF     1460 non-null   float64
#  47  OpenPorchSF    1460 non-null   float64
#  48  EnclosedPorch  1460 non-null   float64
#  49  3SsnPorch      1460 non-null   float64
#  50  ScreenPorch    1460 non-null   float64
#  51  PoolArea       1460 non-null   float64
#  52  MiscVal        1460 non-null   float64
#  53  MoSold         1460 non-null   float64
#  54  YrSold         1460 non-null   float64
#  55  target         1460 non-null   float64
# dtypes: float64(37), object(19)
# memory usage: 638.9+ KB

# %%
# identify how many categorical columns of data we have i.e. variables with data type object

categorical_cols = list(housing_df_cleaned.select_dtypes(['object']).columns)
print("number of categorical columns:", len(categorical_cols))
# Out:
# number of categorical columns: 19

# %%
# print the categorical cols

categorical_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'BldgType',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'GarageFinish',
#  'PavedDrive']

# %%
# encode all the categorical data

categorical_columns = list(housing_df_cleaned.select_dtypes(['object']).columns) # identify all the categorical columns

housing_df_w_encoding = one_hot(housing_df_cleaned, categorical_columns)

# shape of the new dataframe
housing_df_w_encoding.shape
# Out:
# (1460, 113)

# %%
# check the info - do we have any categorical data left?
# we should only have floats and uint. If this is not the case, stop and go back

housing_df_w_encoding.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 113 entries, MSSubClass to PavedDrive_Y
# dtypes: bool(76), float64(37)
# memory usage: 530.5 KB

# %%
# drop correlated features

housing_df_final = housing_df_w_encoding.drop(['GarageArea'], axis = 1)

# you can also look at which features are highly correlated with target when making decision which feature to drop

# %%
# shape of the data went from 60 columns to 113 columns. We did not drop any rows of data.

print(housing_df.shape)
print(housing_df_final.shape)
# Out:
# (1460, 60)
# (1460, 112)

# %%
# save the file

housing_df_final.to_pickle("../data/housing_df_final.pkl")

# %% [markdown]
# - We have handled all the missing data, encoded the 19 variables with data type object and dropped the correlated feature.
# - Since we have no missing data and non numerical data types, we are one step closer to building our ML models.

# %% [markdown]
# ### Build the Decision Tree Model

# %%
# define the target and features

target = housing_df_final["target"]
features = housing_df_final.drop(["target"], axis = 1)

# %%
target.shape
# Out:
# (1460,)

# %%
features.shape
# Out:
# (1460, 111)

# %%
# split the data into train and test set

X_train, X_test, y_train, y_test = train_test_split(
                                                features, 
                                                target,
                                                test_size = 0.3, 
                                                random_state = 8)

# %%
# print the shape of the training data

print("Training Data")
print("Shape of X_train", X_train.shape)
print("Shape of y_train", y_train.shape)
# Out:
# Training Data
# Shape of X_train (1022, 111)
# Shape of y_train (1022,)

# %%
# print the shape of the test data 

print("Test Data")
print("Shape of X_test", X_test.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Test Data
# Shape of X_test (438, 111)
# Shape of y_test (438,)

# %%
# Build a Decision Tree Model

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# %%
print("first five predicted values:", y_pred_dt[0:5])
print("first five actual values:", list(y_test[0:5]))
# Out:
# first five predicted values: [231500. 124900. 112500. 176000. 187000.]
# first five actual values: [181000.0, 124500.0, 114500.0, 155000.0, 187500.0]

# %%
# residual plot

plt.rcParams["figure.figsize"] = (10,5)

residuals = y_test - y_pred_dt

plt.scatter(residuals, y_pred_dt)
plt.title("Residual Plot for the Decision Tree Model")
plt.xlabel("Residuals")
plt.ylabel("Predicted Value")
plt.show();

# we want them the points to be centred around 0

# %%
# the evaluation metrics for the model on the test set
r2 = r2_score(y_test, y_pred_dt)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_test, y_pred_dt)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_test, y_pred_dt)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_test, y_pred_dt)
print("Mean Squared Error:", round(mse))
# Out:
# R2: 0.69
# Explained Variance: 0.7
# Mean Absolute Error: 25051
# Mean Squared Error: 1628067564

# %%
# the evaluation metrics for the model on the training set

y_pred_train_dt = dt.predict(X_train)

r2 = r2_score(y_train, y_pred_train_dt)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_train, y_pred_train_dt)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_train, y_pred_train_dt)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_train, y_pred_train_dt)
print("Mean Squared Error:", round(mse))

# seeing low error rates on the training set, in this case no error rate - signs of overfitting
# Out:
# R2: 1.0
# Explained Variance: 1.0
# Mean Absolute Error: 0
# Mean Squared Error: 0

# %%
learning_curve_plot(dt, X_train, y_train, scoring = 'r2')

# what can we conclude about the decisiom tree model based on the learning curves?

# %%
# feature importance plot

feature_importance_plot(dt, X_train, 10)

# %%
# what are the top 20 lowest features

feat_importances = pd.Series(dt.feature_importances_,
                                 index = X_train.columns)
feat_importance_df = pd.DataFrame(feat_importances).sort_values(by = 0).reset_index().rename(columns = {'index': 'feature',
                                                                                        0: 'score'})
feat_importance_df.head(20)

# we can see 18 features with no feature importance at all
# next iteration, we could remove features with no importance and see if this improves
# we could also consider a threshold for redundant features
# Out:
#               feature  score
# 0       LotConfig_FR3    0.0
# 1    Utilities_NoSeWa    0.0
# 2        LotShape_IR3    0.0
# 3        LotShape_IR2    0.0
# 4         Street_Pave    0.0
# 5         Street_Grvl    0.0
# 6        PavedDrive_P    0.0
# 7       LandSlope_Gtl    0.0
# 8            PoolArea    0.0
# 9     BldgType_2fmCon    0.0
# 10    BldgType_Duplex    0.0
# 11     BldgType_Twnhs    0.0
# 12  MasVnrType_BrkCmn    0.0
# 13    LandContour_Low    0.0
# 14       ExterCond_Ex    0.0
# 15       ExterCond_Po    0.0
# 16       ExterQual_Ex    0.0
# 17   Utilities_AllPub    0.0
# 18       HeatingQC_Po    0.0
# 19        BsmtCond_Po    0.0

# %% [markdown]
# ## Build a Random Forest Model

# %%
# Build a Random Forest Model

rf = RandomForestRegressor()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
# the evaluation metrics for the model on the test set
r2 = r2_score(y_test, y_pred_rf)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_test, y_pred_rf)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_test, y_pred_rf)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_test, y_pred_rf)
print("Mean Squared Error:", round(mse))
# Out:
# R2: 0.84
# Explained Variance: 0.84
# Mean Absolute Error: 17454
# Mean Squared Error: 859600677

# %%
# the evaluation metrics for the model on the training set

y_pred_train_rf = rf.predict(X_train)

r2 = r2_score(y_train, y_pred_train_rf)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_train, y_pred_train_rf)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_train, y_pred_train_rf)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_train, y_pred_train_rf)
print("Mean Squared Error:", round(mse))

# seeing low error rates on the training set, in this case no error rate - signs of overfitting
# Out:
# R2: 0.98
# Explained Variance: 0.98
# Mean Absolute Error: 6687
# Mean Squared Error: 131236061

# %%
learning_curve_plot(rf, X_train, y_train, scoring = 'r2')

# what can we conclude about the random forest model based on the learning curves? less overfitting

# %%
feature_importance_plot(rf, X_train, n = 10)

# %% [markdown]
# ## Build a XGBoostModel

# %%
# Build a XGBoost

xgb = XGBRegressor()
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

# %%
# the evaluation metrics for the model on the test set
r2 = r2_score(y_test, y_pred_xgb)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_test, y_pred_xgb)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_test, y_pred_xgb)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_test, y_pred_xgb)
print("Mean Squared Error:", round(mse))
# Out:
# R2: 0.79
# Explained Variance: 0.79
# Mean Absolute Error: 18871
# Mean Squared Error: 1132266317

# %%
# the evaluation metrics for the model on the training set

y_pred_train_xgb = xgb.predict(X_train)

r2 = r2_score(y_train, y_pred_train_xgb)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_train, y_pred_train_xgb)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_train, y_pred_train_xgb)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_train, y_pred_train_xgb)
print("Mean Squared Error:", round(mse))

# seeing low error rates on the training set, in this case no error rate - signs of overfitting
# Out:
# R2: 1.0
# Explained Variance: 1.0
# Mean Absolute Error: 644
# Mean Squared Error: 776056

# %%
learning_curve_plot(xgb, X_train, y_train, scoring = 'r2')

# %%
feature_importance_plot(xgb, X_train, n = 10)

# %%
# code that Jesus wrote to aggregate all the results

results_table=pd.DataFrame({"Algorithm Name":["Decision Tree","Random Forest","XGBoost"],
              "R2 score":[round(r2_score(y_test, y_pred_dt),2),round(r2_score(y_test, y_pred_rf),2),round(r2_score(y_test, y_pred_xgb),2)],
             "MSE":[round(mean_squared_error(y_test, y_pred_dt)),round(mean_squared_error(y_test, y_pred_rf)), round(mean_squared_error(y_test, y_pred_xgb))],
             "MAE":[round(mean_absolute_error(y_test, y_pred_dt)),round(mean_absolute_error(y_test, y_pred_rf)),round(mean_absolute_error(y_test, y_pred_xgb))],
             "Overfitting or Underfitting?":["Overfitting","Overfitting","Overfitting"]})

results_table.sort_values(by = "R2 score", ascending = False)
# Out:
#   Algorithm Name  R2 score         MSE    MAE Overfitting or Underfitting?
# 1  Random Forest      0.84   859600677  17454                  Overfitting
# 2        XGBoost      0.79  1132266317  18871                  Overfitting
# 0  Decision Tree      0.69  1628067564  25051                  Overfitting

# %% [markdown]
# Summary
#
# - We selected three machine learning algorithms, predominantly decision tree based because of the distribution of the data (skewed data).
# - The Random Forest Model slightly outperformed the other models in terms of performance metrics (had the highest r2 and lowest MSE, MAE)
# - However, when looking at the models in more detail, we saw signs of overfitting and signs of high variance, which was clear from the gap in the learning curves and the differences in metrics on the training and test set. This means the model is just memorising the data, and we can not trust it to generalise well to new data.
# - Next steps would include reducing the number features (we can do this by removing redundant features), could also try to remove OveralQual as this is highly correlated with the target and could be causing the overfitting and seeing if that shows any signs of improvements, and also some hyperparameter tuning.

# %% [markdown]
# ### Hyperparameter Tuning

# %%
RandomForestRegressor(n_estimators=500)
# Out:
# RandomForestRegressor()

# %%
# Let’s say we want to span the n_estimators hyperparameter from 100 to 500 with a step of 100 and the max_features hyperparameter from 0.1 to 1.0 with a step of 0.05. We are looking for the combination of these ranges that maximizes the average value of R2 in 5-fold cross-validation

params = {'n_estimators':np.arange(100,500,100),
          'max_features':np.arange(0.1,1.0,0.2)
         }

# %%
from sklearn.model_selection import GridSearchCV

# Grid search is a tuning technique that attempts to compute the optimum values of hyperparameters. 
# It is an exhaustive search that is performed on a the specific parameter values of a model. 
# The model is also known as an estimator. Grid search exercise can save us time, effort and resources.

grid_search = GridSearchCV(rf,
                           params,
                           cv=5, 
                           scoring="r2",
                           verbose=1,
                           n_jobs=-1
                           )
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_features': array([0.1, 0.3, 0.5, 0.7, 0.9]),
#                          'n_estimators': array([100, 200, 300, 400])},
#              scoring='r2', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_features': 0.30000000000000004, 'n_estimators': 400}

# %%
grid_search.best_score_
# Out:
# 0.8780445286631828

# %%
# pass in the best parameters

rf_tuned = RandomForestRegressor(**grid_search.best_params_)
rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features=0.30000000000000004, n_estimators=400)

# %%
# evaluation on unseen data

y_pred_rf = rf_tuned.predict(X_test)

r2 = r2_score(y_test, y_pred_rf)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_test, y_pred_rf)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_test, y_pred_rf)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_test, y_pred_rf)
print("Mean Squared Error:", round(mse))

# reduction in the MAE and slight increase in R2
# Out:
# R2: 0.83
# Explained Variance: 0.84
# Mean Absolute Error: 16527
# Mean Squared Error: 874529261

# %%
# the evaluation metrics for the model on the training set

y_pred_train_rf = rf_tuned.predict(X_train)

r2 = r2_score(y_train, y_pred_train_rf)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_train, y_pred_train_rf)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_train, y_pred_train_rf)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_train, y_pred_train_rf)
print("Mean Squared Error:", round(mse))
# Out:
# R2: 0.98
# Explained Variance: 0.98
# Mean Absolute Error: 6239
# Mean Squared Error: 118797574

# %%
learning_curve_plot(rf_tuned, X_train, y_train, scoring = 'r2')

# model still overfitting need to do some tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# if Grid search is taking too long, can use Random search,
# Random search is a technique where random combinations of the hyperparameters are used to find the best solution for the built model. 
# The selection of parameters is completely random.

random_search = RandomizedSearchCV(rf,
                                   params,
                                   cv=5,
                                   scoring="r2",
                                   verbose=1,
                                   n_jobs=-1, 
                                   random_state = 0
                                  )
random_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_features': array([0.1, 0.3, 0.5, 0.7, 0.9]),
#                                         'n_estimators': array([100, 200, 300, 400])},
#                    random_state=0, scoring='r2', verbose=1)

# %%
random_search.best_params_

# same as the Grid search
# Out:
# {'n_estimators': 100, 'max_features': 0.5000000000000001}

# %%
random_search.best_score_

# feel free to check if the parameters from the random search reduce overfitting
# Out:
# 0.8795822866768042

# %% [markdown]
# ### Removing Redundant Features

# %%
# identify least important feature based on a threshold

feat_importances = pd.Series(rf.feature_importances_,
                             index = X_train.columns)
feat_importance_df = pd.DataFrame(feat_importances).sort_values(by = 0).reset_index().rename(columns = {'index': 'feature',
                                                                                        0: 'score'})
feats_to_drop = list(feat_importance_df[feat_importance_df.score < 0.01].feature)
print(feats_to_drop)
# Out:
# ['ExterCond_Po', 'LotConfig_FR3', 'HeatingQC_Po', 'BsmtCond_Po', 'Utilities_AllPub', 'Utilities_NoSeWa', 'ExterCond_Ex', 'MasVnrType_BrkCmn', 'Street_Grvl', 'MSZoning_RH', 'BldgType_Twnhs', 'BldgType_2fmCon', 'Street_Pave', '3SsnPorch', 'ExterQual_Fa', 'BsmtCond_Unknown', 'LotConfig_FR2', 'LandSlope_Sev', 'LandContour_Low', 'BldgType_TwnhsE', 'PavedDrive_P', 'MiscVal', 'BsmtQual_Unknown', 'BsmtExposure_Unknown', 'LotShape_IR2', 'KitchenQual_Fa', 'LowQualFinSF', 'PavedDrive_Y', 'GarageFinish_Unknown', 'HeatingQC_Fa', 'BldgType_Duplex', 'ExterCond_Gd', 'BsmtExposure_Mn', 'BsmtQual_Fa', 'BsmtCond_Gd', 'PavedDrive_N', 'MSZoning_FV', 'BldgType_1Fam', 'ExterCond_TA', 'ExterCond_Fa', 'BsmtCond_Fa', 'LotConfig_CulDSac', 'BsmtExposure_Av', 'HeatingQC_TA', 'HeatingQC_Gd', 'BsmtCond_TA', 'MSZoning_C (all)', 'LandContour_HLS', 'HeatingQC_Ex', 'MSZoning_RL', 'LandSlope_Gtl', 'LotShape_IR3', 'BsmtFinSF2', 'GarageFinish_Fin', 'BsmtQual_TA', 'BsmtHalfBath', 'LotShape_Reg', 'PoolArea', 'LandSlope_Mod', 'GarageFinish_RFn', 'ExterQual_Gd', 'MasVnrType_BrkFace', 'MasVnrType_Unknown', 'LandContour_Bnk', 'LandContour_Lvl', 'ExterQual_Ex', 'BsmtExposure_No', 'MasVnrType_Stone', 'KitchenAbvGr', 'LotConfig_Corner', 'EnclosedPorch', 'HalfBath', 'ExterQual_TA', 'LotShape_IR1', 'CentralAir_Y', 'LotConfig_Inside', 'BsmtFullBath', 'YrSold', 'KitchenQual_TA', 'KitchenQual_Ex', 'BsmtExposure_Gd', 'ScreenPorch', 'MSZoning_RM', 'BedroomAbvGr', 'CentralAir_N', 'KitchenQual_Gd', 'BsmtQual_Gd', 'MSSubClass', 'GarageFinish_Unf', 'Fireplaces', 'MoSold', 'BsmtQual_Ex', 'OverallCond', 'BsmtUnfSF', 'OpenPorchSF', 'LotFrontage', 'WoodDeckSF', 'MasVnrArea', 'TotRmsAbvGrd', 'FullBath', 'GarageYrBlt', 'YearRemodAdd', 'YearBuilt']

# %%
# define the target and features

print(features.shape)
features.drop(feats_to_drop, axis = 1, inplace = True) # drop redundant features
print(features.shape)
# Out:
# (1460, 111)
# (1460, 8)

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                                features, 
                                                target,
                                                test_size = 0.3, 
                                                random_state = 8)

# %%
# Build a Random Forest Model

rf_wout_redundant_features = RandomForestRegressor()
rf_wout_redundant_features.fit(X_train, y_train)
y_pred_rf = rf_wout_redundant_features.predict(X_test)

# %%
# evaluation on unseen data

y_pred_rf = rf_wout_redundant_features.predict(X_test)

r2 = r2_score(y_test, y_pred_rf)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_test, y_pred_rf)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_test, y_pred_rf)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_test, y_pred_rf)
print("Mean Squared Error:", round(mse))
# Out:
# R2: 0.77
# Explained Variance: 0.78
# Mean Absolute Error: 20503
# Mean Squared Error: 1196795534

# %%
# the evaluation metrics for the model on the training set

y_pred_train_rf = rf_wout_redundant_features.predict(X_train)

r2 = r2_score(y_train, y_pred_train_rf)
print("R2:", round(r2, 2))
explained_var = explained_variance_score(y_train, y_pred_train_rf)
print("Explained Variance:", round(explained_var, 2))
mae = mean_absolute_error(y_train, y_pred_train_rf)
print("Mean Absolute Error:", round(mae))
mse = mean_squared_error(y_train, y_pred_train_rf)
print("Mean Squared Error:", round(mse))
# Out:
# R2: 0.98
# Explained Variance: 0.98
# Mean Absolute Error: 7362
# Mean Squared Error: 137407609

# %%
learning_curve_plot(rf_wout_redundant_features, X_train, y_train, scoring = 'r2')

# %%
# could tune the model with the removed redundant features to see if this would reduce overfitting
# could also try to remove the variable overqual
